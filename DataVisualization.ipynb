# %%
import numpy as np
from numpy import exp,array,random,dot
import pandas as pd

import matplotlib
import matplotlib.pyplot as plt
# %matplotlib inline
plt.rcParams['figure.figsize'] = (12.0, 8.0)

import seaborn as sns

# %%
# Reading data from csv
data = pd.read_csv("data/train.csv")

# %%
# Pandas DataFrame Information
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 38973 entries, 0 to 38972
# Data columns (total 16 columns):
# id                38973 non-null int64
# age               38973 non-null int64
# workclass         38973 non-null object
# fnlwgt            38973 non-null int64
# education         38973 non-null object
# education-num     38973 non-null int64
# marital-status    38973 non-null object
# occupation        38973 non-null object
# relationship      38973 non-null object
# race              38973 non-null object
# sex               38973 non-null object
# capital-gain      38973 non-null int64
# capital-loss      38973 non-null int64
# hours-per-week    38973 non-null int64
# native-country    38973 non-null object
# salary            38973 non-null int64
# dtypes: int64(8), object(8)
# memory usage: 4.8+ MB

# %%
data = data.drop('id', axis=1)
dataframe = dataframe[data['occupation'] != '?']
dataframe = dataframe[data['workclass'] != '?']
dataframe = dataframe[data['native.country'] != '?']
print(data)
# Out:
#        age          workclass  fnlwgt      education  education-num  \
# 0       25            Private  226802           11th              7
# 1       38            Private   89814        HS-grad              9
# 2       28          Local-gov  336951     Assoc-acdm             12
# 3       44            Private  160323   Some-college             10
# 4       34            Private  198693           10th              6
# 5       63   Self-emp-not-inc  104626    Prof-school             15
# 6       24            Private  369667   Some-college             10
# 7       55            Private  104996        7th-8th              4
# 8       65            Private  184454        HS-grad              9
# 9       26            Private   82091        HS-grad              9
# 10      58                  ?  299831        HS-grad              9
# 11      48            Private  279724        HS-grad              9
# 12      20          State-gov  444554   Some-college             10
# ...

# %%
# Heatmap for visualizing correlation between features
plt.figure(figsize=(15,10))
colormap = plt.cm.viridis_r
sns.heatmap(data.corr(), vmax=1.0, cmap="YlGnBu", annot=True)
plt.show()

# %%
# Plotting Scatter Plots using Seaborn
sns.lmplot('age', 'education-num', data=data, fit_reg=False)

# Plotting Scatter Plots using Pandas
data.plot.scatter(x='age', y='education-num', c='k', alpha=.15)

# %%
# Density Plot
sns.kdeplot(data.age)

# %%
# Plots uding Seaborn
sns.countplot(x='salary', data=data)
sns.despine()

# %%
# Boxplots using Seaborn
sns.barplot(x='race', y='salary', data=data)
sns.despine()

# %%
g = sns.pairplot(data, hue='salary')

# %%
g = sns.FacetGrid(data, row='education-num', aspect=4, size=1.76, margin_titles=True)
g.map(sns.kdeplot, 'salary', shade=True, color='k')
for ax in g.axes.flat:
    ax.yaxis.set_visible(False)
sns.despine(left=True)
g.fig.subplots_adjust(hspace=0.1)
g.set(xlim=(0,1))

# %%
g = sns.FacetGrid(data, row='relationship', col='salary')
g.map(sns.distplot, "age")
sns.plt.show()
